# %% [markdown]
# <a href="https://colab.research.google.com/github/unachankz/goto_data_science/blob/master/PCBdata_fasterRCNN_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# You can check [here](https://github.com/facebookresearch/detectron2/blob/master/INSTALL.md) to get needed environment, but you don't need to worry it in colab.

# %%
# install dependencies: (use cu101 because colab has CUDA 10.1)
# !pip install -U torch==1.5 torchvision==0.6 -f https://download.pytorch.org/whl/cu101/torch_stable.html 
# !pip install cython pyyaml==5.1
# !pip install -U 'git+https://github.com/cocodataset/cocoapi.git#subdirectory=PythonAPI'
import torch, torchvision
print(torch.__version__, torch.cuda.is_available())
# !gcc --version
# opencv is pre-installed on colab
# Out:
# Looking in links: https://download.pytorch.org/whl/cu101/torch_stable.html
# Collecting torch==1.5
#   Downloading https://download.pytorch.org/whl/cu101/torch-1.5.0%2Bcu101-cp36-cp36m-linux_x86_64.whl (703.8MB)
#      |████████████████████████████████| 703.8MB 26kB/s
# Collecting torchvision==0.6
#   Downloading https://download.pytorch.org/whl/cu101/torchvision-0.6.0%2Bcu101-cp36-cp36m-linux_x86_64.whl (6.6MB)
#      |████████████████████████████████| 6.6MB 3.6MB/s
# Requirement already satisfied, skipping upgrade: future in /usr/local/lib/python3.6/dist-packages (from torch==1.5) (0.16.0)
# Requirement already satisfied, skipping upgrade: numpy in /usr/local/lib/python3.6/dist-packages (from torch==1.5) (1.19.5)
# Requirement already satisfied, skipping upgrade: pillow>=4.1.1 in /usr/local/lib/python3.6/dist-packages (from torchvision==0.6) (7.0.0)
# Installing collected packages: torch, torchvision
#   Found existing installation: torch 1.7.0+cu101
#     Uninstalling torch-1.7.0+cu101:
#       Successfully uninstalled torch-1.7.0+cu101
#   Found existing installation: torchvision 0.8.1+cu101
#     Uninstalling torchvision-0.8.1+cu101:
#       Successfully uninstalled torchvision-0.8.1+cu101
# Successfully installed torch-1.5.0+cu101 torchvision-0.6.0+cu101
# Requirement already satisfied: cython in /usr/local/lib/python3.6/dist-packages (0.29.21)
# Collecting pyyaml==5.1
#   Downloading https://files.pythonhosted.org/packages/9f/2c/9417b5c774792634834e730932745bc09a7d36754ca00acf1ccd1ac2594d/PyYAML-5.1.tar.gz (274kB)
#      |████████████████████████████████| 276kB 14.2MB/s
# Building wheels for collected packages: pyyaml
#   Building wheel for pyyaml (setup.py) ... done
#   Created wheel for pyyaml: filename=PyYAML-5.1-cp36-cp36m-linux_x86_64.whl size=44075 sha256=c6b161e57f0c717df552b737e0769e90373cbc3b2df86f41ed312fa2223b239a
#   Stored in directory: /root/.cache/pip/wheels/ad/56/bc/1522f864feb2a358ea6f1a92b4798d69ac783a28e80567a18b
# Successfully built pyyaml
# Installing collected packages: pyyaml
#   Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# Successfully installed pyyaml-5.1
# Collecting git+https://github.com/cocodataset/cocoapi.git#subdirectory=PythonAPI
#   Cloning https://github.com/cocodataset/cocoapi.git to /tmp/pip-req-build-9ge1wxhu
#   Running command git clone -q https://github.com/cocodataset/cocoapi.git /tmp/pip-req-build-9ge1wxhu
# Requirement already satisfied, skipping upgrade: setuptools>=18.0 in /usr/local/lib/python3.6/dist-packages (from pycocotools==2.0) (51.3.3)
# Requirement already satisfied, skipping upgrade: cython>=0.27.3 in /usr/local/lib/python3.6/dist-packages (from pycocotools==2.0) (0.29.21)
# Requirement already satisfied, skipping upgrade: matplotlib>=2.1.0 in /usr/local/lib/python3.6/dist-packages (from pycocotools==2.0) (3.2.2)
# Requirement already satisfied, skipping upgrade: pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=2.0.1 in /usr/local/lib/python3.6/dist-packages (from matplotlib>=2.1.0->pycocotools==2.0) (2.4.7)
# Requirement already satisfied, skipping upgrade: cycler>=0.10 in /usr/local/lib/python3.6/dist-packages (from matplotlib>=2.1.0->pycocotools==2.0) (0.10.0)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.1 in /usr/local/lib/python3.6/dist-packages (from matplotlib>=2.1.0->pycocotools==2.0) (2.8.1)
# Requirement already satisfied, skipping upgrade: kiwisolver>=1.0.1 in /usr/local/lib/python3.6/dist-packages (from matplotlib>=2.1.0->pycocotools==2.0) (1.3.1)
# Requirement already satisfied, skipping upgrade: numpy>=1.11 in /usr/local/lib/python3.6/dist-packages (from matplotlib>=2.1.0->pycocotools==2.0) (1.19.5)
# Requirement already satisfied, skipping upgrade: six in /usr/local/lib/python3.6/dist-packages (from cycler>=0.10->matplotlib>=2.1.0->pycocotools==2.0) (1.15.0)
# Building wheels for collected packages: pycocotools
#   Building wheel for pycocotools (setup.py) ... done
#   Created wheel for pycocotools: filename=pycocotools-2.0-cp36-cp36m-linux_x86_64.whl size=265566 sha256=15a10c3cb30b4ba535d6610ae9382ad72fd394cd4f77d06d5fbe5501c12bc291
#   Stored in directory: /tmp/pip-ephem-wheel-cache-8ejhblwy/wheels/90/51/41/646daf401c3bc408ff10de34ec76587a9b3ebfac8d21ca5c3a
# Successfully built pycocotools
# Installing collected packages: pycocotools
#   Found existing installation: pycocotools 2.0.2
#     Uninstalling pycocotools-2.0.2:
#       Successfully uninstalled pycocotools-2.0.2
# Successfully installed pycocotools-2.0
# 1.5.0+cu101 True
# gcc (Ubuntu 7.5.0-3ubuntu1~18.04) 7.5.0
# Copyright (C) 2017 Free Software Foundation, Inc.
# This is free software; see the source for copying conditions.  There is NO
# warranty; not even for MERCHANTABILITY or FITNESS FOR A PARTICULAR PURPOSE.

# %%
# !git clone https://github.com/tangsanli5201/DeepPCB
# install detectron2:
# !pip install detectron2==0.1.3 -f https://dl.fbaipublicfiles.com/detectron2/wheels/cu101/torch1.5/index.html
# Out:
# Cloning into 'DeepPCB'...
# remote: Enumerating objects: 4753, done.
# remote: Total 4753 (delta 0), reused 0 (delta 0), pack-reused 4753
# Receiving objects: 100% (4753/4753), 85.81 MiB | 35.66 MiB/s, done.
# Resolving deltas: 100% (191/191), done.
# Looking in links: https://dl.fbaipublicfiles.com/detectron2/wheels/cu101/torch1.5/index.html
# Collecting detectron2==0.1.3
#   Downloading https://dl.fbaipublicfiles.com/detectron2/wheels/cu101/torch1.5/detectron2-0.1.3%2Bcu101-cp36-cp36m-linux_x86_64.whl (6.2MB)
#      |████████████████████████████████| 6.2MB 576kB/s
# Requirement already satisfied: tqdm>4.29.0 in /usr/local/lib/python3.6/dist-packages (from detectron2==0.1.3) (4.41.1)
# Collecting yacs>=0.1.6
#   Downloading https://files.pythonhosted.org/packages/38/4f/fe9a4d472aa867878ce3bb7efb16654c5d63672b86dc0e6e953a67018433/yacs-0.1.8-py3-none-any.whl
# Requirement already satisfied: pydot in /usr/local/lib/python3.6/dist-packages (from detectron2==0.1.3) (1.3.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.6/dist-packages (from detectron2==0.1.3) (3.2.2)
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.6/dist-packages (from detectron2==0.1.3) (2.4.1)
# Collecting mock
#   Downloading https://files.pythonhosted.org/packages/5c/03/b7e605db4a57c0f6fba744b11ef3ddf4ddebcada35022927a2b5fc623fdf/mock-4.0.3-py3-none-any.whl
# Requirement already satisfied: termcolor>=1.1 in /usr/local/lib/python3.6/dist-packages (from detectron2==0.1.3) (1.1.0)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.6/dist-packages (from detectron2==0.1.3) (1.3.0)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from detectron2==0.1.3) (0.16.0)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.6/dist-packages (from detectron2==0.1.3) (7.0.0)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.6/dist-packages (from detectron2==0.1.3) (0.8.7)
# Collecting fvcore>=0.1.1
#   Downloading https://files.pythonhosted.org/packages/78/eb/d1aff86ce51a43dc6f45c4af9ea3dbde52fd04eb46c68d74b4689b081b24/fvcore-0.1.2.post20210128.tar.gz
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.6/dist-packages (from yacs>=0.1.6->detectron2==0.1.3) (5.1)
# Requirement already satisfied: pyparsing>=2.1.4 in /usr/local/lib/python3.6/dist-packages (from pydot->detectron2==0.1.3) (2.4.7)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.6/dist-packages (from matplotlib->detectron2==0.1.3) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.6/dist-packages (from matplotlib->detectron2==0.1.3) (1.3.1)
# Requirement already satisfied: numpy>=1.11 in /usr/local/lib/python3.6/dist-packages (from matplotlib->detectron2==0.1.3) (1.19.5)
# Requirement already satisfied: python-dateutil>=2.1 in /usr/local/lib/python3.6/dist-packages (from matplotlib->detectron2==0.1.3) (2.8.1)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /usr/local/lib/python3.6/dist-packages (from tensorboard->detectron2==0.1.3) (1.17.2)
# Requirement already satisfied: grpcio>=1.24.3 in /usr/local/lib/python3.6/dist-packages (from tensorboard->detectron2==0.1.3) (1.32.0)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard->detectron2==0.1.3) (2.23.0)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard->detectron2==0.1.3) (1.15.0)
# Requirement already satisfied: wheel>=0.26; python_version >= "3" in /usr/local/lib/python3.6/dist-packages (from tensorboard->detectron2==0.1.3) (0.36.2)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tensorboard->detectron2==0.1.3) (3.3.3)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.6/dist-packages (from tensorboard->detectron2==0.1.3) (0.4.2)
# Requirement already satisfied: protobuf>=3.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard->detectron2==0.1.3) (3.12.4)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard->detectron2==0.1.3) (1.8.0)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard->detectron2==0.1.3) (51.3.3)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tensorboard->detectron2==0.1.3) (1.0.1)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.6/dist-packages (from tensorboard->detectron2==0.1.3) (0.10.0)
# Collecting iopath>=0.1.2
#   Downloading https://files.pythonhosted.org/packages/f2/c8/1830019bcecf26e76c3fdc36e2a6fa454388a233894dcf6f5eb00a881468/iopath-0.1.3.tar.gz
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard->detectron2==0.1.3) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard->detectron2==0.1.3) (4.2.1)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3" in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard->detectron2==0.1.3) (4.7)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard->detectron2==0.1.3) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard->detectron2==0.1.3) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard->detectron2==0.1.3) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard->detectron2==0.1.3) (2020.12.5)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from markdown>=2.6.8->tensorboard->detectron2==0.1.3) (3.4.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard->detectron2==0.1.3) (1.3.0)
# Collecting portalocker
#   Downloading https://files.pythonhosted.org/packages/14/47/43fdee732cda080367c7d2a1ee5aee3b31e49baf629029a386df458d2dd3/portalocker-2.2.0-py2.py3-none-any.whl
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.6/dist-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard->detectron2==0.1.3) (0.4.8)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard->detectron2==0.1.3) (3.4.0)
# Requirement already satisfied: typing-extensions>=3.6.4; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard->detectron2==0.1.3) (3.7.4.3)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard->detectron2==0.1.3) (3.1.0)
# Building wheels for collected packages: fvcore, iopath
#   Building wheel for fvcore (setup.py) ... done
#   Created wheel for fvcore: filename=fvcore-0.1.2.post20210128-cp36-none-any.whl size=41550 sha256=2803dd102ad3b7eeab65d7aa62f631bc3c12aafe5fe06fd27d7dd687b9a928cf
#   Stored in directory: /root/.cache/pip/wheels/2e/2e/1b/c208cf351dc8ccefa6e483df7d2cb287b2b06727f650b2361d
#   Building wheel for iopath (setup.py) ... done
#   Created wheel for iopath: filename=iopath-0.1.3-cp36-none-any.whl size=11169 sha256=bce3e9b27a571a83acbf9d41515b2a18184f775f4160d32932195cdb52e923e7
#   Stored in directory: /root/.cache/pip/wheels/a9/1d/55/94a55e032409ac7617f9cbb88a0fa2cf4e7208806c29730804
# Successfully built fvcore iopath
# Installing collected packages: yacs, mock, portalocker, iopath, fvcore, detectron2
# Successfully installed detectron2-0.1.3+cu101 fvcore-0.1.2.post20210128 iopath-0.1.3 mock-4.0.3 portalocker-2.2.0 yacs-0.1.8

# %%
# You may need to restart your runtime prior to this, to let your installation take effect
# Some basic setup
# Setup detectron2 logger
import detectron2
from detectron2.utils.logger import setup_logger
setup_logger()

# import some common libraries
import numpy as np
import cv2
import random
#from google.colab.patches import cv2_imshow

# import some common detectron2 utilities
from detectron2 import model_zoo
from detectron2.engine import DefaultPredictor
from detectron2.config import get_cfg
from detectron2.utils.visualizer import Visualizer
from detectron2.data import MetadataCatalog
# Out:
# ** fvcore version of PathManager will be deprecated soon. **
# ** Please migrate to the version in iopath repo. **
# https://github.com/facebookresearch/iopath

# %%
# !git clone https://github.com/facebookresearch/detectron2/
# Out:
# Cloning into 'detectron2'...
# remote: Enumerating objects: 1, done.
# remote: Counting objects: 100% (1/1), done.
# remote: Total 10051 (delta 0), reused 1 (delta 0), pack-reused 10050
# Receiving objects: 100% (10051/10051), 4.16 MiB | 25.79 MiB/s, done.
# Resolving deltas: 100% (7280/7280), done.

# %%
import matplotlib.pyplot as plt
import torchvision.transforms as transforms
from matplotlib.pyplot import imshow
from PIL import Image
import IPython
def cv2_imshow(img):
    img = img[:,:,[2,1,0]]
    img = Image.fromarray(img)
    plt.figure(figsize=(20, 20))
    plt.imshow(img)
    plt.axis('off')
    plt.show()

# %% [markdown]
# We have to take the data out from the .txt file.

# %%
import csv
train, test = [],[]
def take_path(x,d):
    with open(d) as t:
        #print(t.read())
        #print(type(csv.reader(t)))
        tmp = csv.reader(t,delimiter=' ')
        for i in tmp:
            x.append(i)
        for ele in x:
            ele[0] = './DeepPCB/PCBData/'+ele[0][:-4]+'_test.jpg'
            ele[1] = './DeepPCB/PCBData/'+ele[1]

take_path(test,'./DeepPCB/PCBData/test.txt')
print(test[:2])
take_path(train,'./DeepPCB/PCBData/trainval.txt')
print(train[:2])
# Out:
# [['./DeepPCB/PCBData/group20085/20085/20085291_test.jpg', './DeepPCB/PCBData/group20085/20085_not/20085291.txt'], ['./DeepPCB/PCBData/group20085/20085/20085292_test.jpg', './DeepPCB/PCBData/group20085/20085_not/20085292.txt']]
# [['./DeepPCB/PCBData/group20085/20085/20085000_test.jpg', './DeepPCB/PCBData/group20085/20085_not/20085000.txt'], ['./DeepPCB/PCBData/group20085/20085/20085001_test.jpg', './DeepPCB/PCBData/group20085/20085_not/20085001.txt']]

# %%
height, width = cv2.imread(test[0][0]).shape[:2]
print(height, width)
# Out:
# 640 640

# %% [markdown]
# # New Section

# %%
import os
import numpy as np
import json
from detectron2.structures import BoxMode

os.environ["CUDA_VISIBLE_DEVICES"] = "0"

#DatasetCatalog.clear()
#If you want to clear the data you registered, uncomment the upper line.

def get_PCB_dict(data_list):
    dataset_dicts = []
    
    for i,path in enumerate(data_list):
        filename = path[0]
        height, width = cv2.imread(filename).shape[:2]
        record = {}
        record['file_name'] = filename
        record['image_id'] = i
        record['height']= height
        record['width']= width
        
        
        objs = []
        with open(path[1]) as t:
            lines = t.readlines()
            for line in lines:
                if line[-1]=="\n":
                  box = line[:-1].split(' ')
                else:
                  box = line.split(' ')


                boxes = list(map(float,[box[0],box[1],box[2],box[3]]))
                category = int(box[4])

                obj = {
                    "bbox": boxes,
                    "bbox_mode": BoxMode.XYXY_ABS,
                    #"segmentation": [poly], To draw a line, along to ballon
                    #you will need this for mask RCNN
                    "category_id": category-1,
                    "iscrowd": 0
                }
                objs.append(obj)
            record["annotations"] = objs
        dataset_dicts.append(record)
    return dataset_dicts #list of dicts

# %%
from detectron2.data import DatasetCatalog, MetadataCatalog
for d,x in [("train",train), ("test",test)]:
    DatasetCatalog.register("PCB_" + d, lambda x=x: get_PCB_dict(x))
    MetadataCatalog.get("PCB_" + d).set(thing_classes=["open", "short", "mousebite", "spur", "copper", "pin-hole"],thing_colors=[(255,0,0),(0,255,0),(0,0,255),(255,255,0),(255,0,255),(0,255,255)])
    #I set the colors, but it's no use. Retry after training.
PCB_metadata = MetadataCatalog.get("PCB_train")

# %%
#check dataset
print(type(PCB_metadata))
MetadataCatalog.get("PCB_test")
# Out:
# <class 'detectron2.data.catalog.Metadata'>
# Metadata(name='PCB_test', thing_classes=['open', 'short', 'mousebite', 'spur', 'copper', 'pin-hole'], thing_colors=[(255, 0, 0), (0, 255, 0), (0, 0, 255), (255, 255, 0), (255, 0, 255), (0, 255, 255)])

# %% [markdown]
# Get all the data and check the content inside

# %%
dataset_dicts = get_PCB_dict(train)

# %%
print(dataset_dicts[0])
print(dataset_dicts[1])
# Out:
# {'file_name': './DeepPCB/PCBData/group20085/20085/20085000_test.jpg', 'image_id': 0, 'height': 640, 'width': 640, 'annotations': [{'bbox': [409.0, 394.0, 435.0, 422.0], 'bbox_mode': <BoxMode.XYXY_ABS: 0>, 'category_id': 2, 'iscrowd': 0}, {'bbox': [275.0, 383.0, 319.0, 417.0], 'bbox_mode': <BoxMode.XYXY_ABS: 0>, 'category_id': 2, 'iscrowd': 0}, {'bbox': [8.0, 163.0, 36.0, 191.0], 'bbox_mode': <BoxMode.XYXY_ABS: 0>, 'category_id': 3, 'iscrowd': 0}, {'bbox': [244.0, 151.0, 270.0, 182.0], 'bbox_mode': <BoxMode.XYXY_ABS: 0>, 'category_id': 4, 'iscrowd': 0}, {'bbox': [338.0, 519.0, 364.0, 543.0], 'bbox_mode': <BoxMode.XYXY_ABS: 0>, 'category_id': 5, 'iscrowd': 0}, {'bbox': [476.0, 460.0, 502.0, 481.0], 'bbox_mode': <BoxMode.XYXY_ABS: 0>, 'category_id': 3, 'iscrowd': 0}]}
# {'file_name': './DeepPCB/PCBData/group20085/20085/20085001_test.jpg', 'image_id': 1, 'height': 640, 'width': 640, 'annotations': [{'bbox': [335.0, 208.0, 364.0, 233.0], 'bbox_mode': <BoxMode.XYXY_ABS: 0>, 'category_id': 2, 'iscrowd': 0}, {'bbox': [429.0, 132.0, 458.0, 159.0], 'bbox_mode': <BoxMode.XYXY_ABS: 0>, 'category_id': 3, 'iscrowd': 0}, {'bbox': [71.0, 149.0, 96.0, 172.0], 'bbox_mode': <BoxMode.XYXY_ABS: 0>, 'category_id': 4, 'iscrowd': 0}, {'bbox': [323.0, 26.0, 350.0, 60.0], 'bbox_mode': <BoxMode.XYXY_ABS: 0>, 'category_id': 5, 'iscrowd': 0}, {'bbox': [585.0, 284.0, 610.0, 310.0], 'bbox_mode': <BoxMode.XYXY_ABS: 0>, 'category_id': 2, 'iscrowd': 0}, {'bbox': [424.0, 346.0, 449.0, 369.0], 'bbox_mode': <BoxMode.XYXY_ABS: 0>, 'category_id': 5, 'iscrowd': 0}, {'bbox': [80.0, 572.0, 105.0, 596.0], 'bbox_mode': <BoxMode.XYXY_ABS: 0>, 'category_id': 4, 'iscrowd': 0}]}

# %%
for d in random.sample(dataset_dicts, 2):
    img = cv2.imread(d["file_name"])
    visualizer = Visualizer(img[:, :, ::-1], metadata=PCB_metadata, scale=0.5)
    vis = visualizer.draw_dataset_dict(d)
    cv2_imshow(vis.get_image()[:, :, ::-1])

# %%
from detectron2.engine import DefaultTrainer
from detectron2.config import get_cfg
from detectron2 import model_zoo

cfg = get_cfg()
# cfg.merge_from_file(model_zoo.get_config_file("COCO-Detection/faster_rcnn_R_50_FPN_3x.yaml"))
cfg.merge_from_file(model_zoo.get_config_file("COCO-Detection/faster_rcnn_X_101_32x8d_FPN_3x.yaml"))
                                                 

cfg.DATASETS.TRAIN = ("PCB_train",)
cfg.DATASETS.TEST = ()
cfg.DATALOADER.NUM_WORKERS = 0
cfg.MODEL.WEIGHTS = model_zoo.get_checkpoint_url("COCO-Detection/faster_rcnn_X_101_32x8d_FPN_3x.yaml") # Let training initialize from model zoo
cfg.SOLVER.IMS_PER_BATCH = 2
cfg.SOLVER.BASE_LR = 0.00025  # pick a good LR
cfg.SOLVER.MAX_ITER = 3000    # 300 iterations seems good enough for this toy dataset; you may need to train longer for a practical dataset
cfg.MODEL.ROI_HEADS.BATCH_SIZE_PER_IMAGE = 4096   # faster, and good enough for this toy dataset (default: 512)
cfg.MODEL.ROI_HEADS.NUM_CLASSES = 6 

os.makedirs(cfg.OUTPUT_DIR, exist_ok=True)
trainer = DefaultTrainer(cfg) 
trainer.resume_or_load(resume=False)

trainer.train()
#It will train about 20 minutes in colab.
# Out:
# [01/31 09:38:13 d2.engine.defaults]: Model:
# GeneralizedRCNN(
#   (backbone): FPN(
#     (fpn_lateral2): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral3): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral4): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output4): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral5): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (top_block): LastLevelMaxPool()
#     (bottom_up): ResNet(
#       (stem): BasicStem(
#         (conv1): Conv2d(
#           3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False
#           (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#         )
#       )
#       (res2): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#       )
#       (res3): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             256, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (3): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#       )
#       (res4): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (3): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (4): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (5): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (6): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (7): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (8): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (9): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (10): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (11): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (12): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (13): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (14): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (15): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (16): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (17): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (18): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (19): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (20): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (21): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (22): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#       )
#       (res5): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             1024, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             2048, 2048, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             2048, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             2048, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             2048, 2048, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             2048, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             2048, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             2048, 2048, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             2048, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#       )
#     )
#   )
#   (proposal_generator): RPN(
#     (anchor_generator): DefaultAnchorGenerator(
#       (cell_anchors): BufferList()
#     )
#     (rpn_head): StandardRPNHead(
#       (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (objectness_logits): Conv2d(256, 3, kernel_size=(1, 1), stride=(1, 1))
#       (anchor_deltas): Conv2d(256, 12, kernel_size=(1, 1), stride=(1, 1))
#     )
#   )
#   (roi_heads): StandardROIHeads(
#     (box_pooler): ROIPooler(
#       (level_poolers): ModuleList(
#         (0): ROIAlign(output_size=(7, 7), spatial_scale=0.25, sampling_ratio=0, aligned=True)
#         (1): ROIAlign(output_size=(7, 7), spatial_scale=0.125, sampling_ratio=0, aligned=True)
#         (2): ROIAlign(output_size=(7, 7), spatial_scale=0.0625, sampling_ratio=0, aligned=True)
#         (3): ROIAlign(output_size=(7, 7), spatial_scale=0.03125, sampling_ratio=0, aligned=True)
#       )
#     )
#     (box_head): FastRCNNConvFCHead(
#       (fc1): Linear(in_features=12544, out_features=1024, bias=True)
#       (fc2): Linear(in_features=1024, out_features=1024, bias=True)
#     )
#     (box_predictor): FastRCNNOutputLayers(
#       (cls_score): Linear(in_features=1024, out_features=7, bias=True)
#       (bbox_pred): Linear(in_features=1024, out_features=24, bias=True)
#     )
#   )
# )
# [01/31 09:38:16 d2.data.build]: Removed 0 images with no usable annotations. 1000 images left.
# [01/31 09:38:16 d2.data.common]: Serializing 1000 elements to byte tensors and concatenating them all ...
# [01/31 09:38:16 d2.data.common]: Serialized dataset takes 0.59 MiB
# [01/31 09:38:16 d2.data.detection_utils]: TransformGens used in training: [ResizeShortestEdge(short_edge_length=(640, 672, 704, 736, 768, 800), max_size=1333, sample_style='choice'), RandomFlip()]
# [01/31 09:38:16 d2.data.build]: Using training sampler TrainingSampler
# model_final_68b088.pkl: 421MB [00:19, 21.8MB/s]
# Skip loading parameter 'roi_heads.box_predictor.cls_score.weight' to the model due to incompatible shapes: (81, 1024) in the checkpoint but (7, 1024) in the model! You might want to double check if this is expected.
# Skip loading parameter 'roi_heads.box_predictor.cls_score.bias' to the model due to incompatible shapes: (81,) in the checkpoint but (7,) in the model! You might want to double check if this is expected.
# Skip loading parameter 'roi_heads.box_predictor.bbox_pred.weight' to the model due to incompatible shapes: (320, 1024) in the checkpoint but (24, 1024) in the model! You might want to double check if this is expected.
# Skip loading parameter 'roi_heads.box_predictor.bbox_pred.bias' to the model due to incompatible shapes: (320,) in the checkpoint but (24,) in the model! You might want to double check if this is expected.
# [01/31 09:38:36 d2.engine.train_loop]: Starting training from iteration 0
# [01/31 09:38:56 d2.utils.events]:  eta: 0:50:01  iter: 19  total_loss: 3.353  loss_cls: 2.138  loss_box_reg: 0.021  loss_rpn_cls: 1.038  loss_rpn_loc: 0.132  time: 1.0077  data_time: 0.0398  lr: 0.000005  max_mem: 5289M
# [01/31 09:39:16 d2.utils.events]:  eta: 0:49:47  iter: 39  total_loss: 2.825  loss_cls: 1.904  loss_box_reg: 0.035  loss_rpn_cls: 0.799  loss_rpn_loc: 0.114  time: 1.0204  data_time: 0.0393  lr: 0.000010  max_mem: 5289M
# [01/31 09:39:37 d2.utils.events]:  eta: 0:50:16  iter: 59  total_loss: 2.306  loss_cls: 1.528  loss_box_reg: 0.053  loss_rpn_cls: 0.507  loss_rpn_loc: 0.144  time: 1.0289  data_time: 0.0390  lr: 0.000015  max_mem: 5290M
# [01/31 09:39:57 d2.utils.events]:  eta: 0:49:36  iter: 79  total_loss: 1.582  loss_cls: 1.121  loss_box_reg: 0.050  loss_rpn_cls: 0.319  loss_rpn_loc: 0.144  time: 1.0174  data_time: 0.0371  lr: 0.000020  max_mem: 5290M
# [01/31 09:40:17 d2.utils.events]:  eta: 0:49:29  iter: 99  total_loss: 1.116  loss_cls: 0.770  loss_box_reg: 0.053  loss_rpn_cls: 0.183  loss_rpn_loc: 0.130  time: 1.0175  data_time: 0.0367  lr: 0.000025  max_mem: 5290M
# [01/31 09:40:38 d2.utils.events]:  eta: 0:48:56  iter: 119  total_loss: 0.758  loss_cls: 0.406  loss_box_reg: 0.083  loss_rpn_cls: 0.114  loss_rpn_loc: 0.120  time: 1.0189  data_time: 0.0378  lr: 0.000030  max_mem: 5290M
# [01/31 09:40:58 d2.utils.events]:  eta: 0:48:33  iter: 139  total_loss: 0.545  loss_cls: 0.241  loss_box_reg: 0.088  loss_rpn_cls: 0.114  loss_rpn_loc: 0.117  time: 1.0160  data_time: 0.0364  lr: 0.000035  max_mem: 5290M
# [01/31 09:41:18 d2.utils.events]:  eta: 0:48:24  iter: 159  total_loss: 0.510  loss_cls: 0.202  loss_box_reg: 0.088  loss_rpn_cls: 0.099  loss_rpn_loc: 0.110  time: 1.0164  data_time: 0.0375  lr: 0.000040  max_mem: 5290M
# [01/31 09:41:39 d2.utils.events]:  eta: 0:47:58  iter: 179  total_loss: 0.624  loss_cls: 0.233  loss_box_reg: 0.136  loss_rpn_cls: 0.133  loss_rpn_loc: 0.116  time: 1.0157  data_time: 0.0384  lr: 0.000045  max_mem: 5290M
# [01/31 09:41:59 d2.utils.events]:  eta: 0:47:24  iter: 199  total_loss: 0.625  loss_cls: 0.292  loss_box_reg: 0.177  loss_rpn_cls: 0.082  loss_rpn_loc: 0.082  time: 1.0139  data_time: 0.0360  lr: 0.000050  max_mem: 5290M
# [01/31 09:42:19 d2.utils.events]:  eta: 0:47:13  iter: 219  total_loss: 0.712  loss_cls: 0.337  loss_box_reg: 0.230  loss_rpn_cls: 0.074  loss_rpn_loc: 0.075  time: 1.0150  data_time: 0.0362  lr: 0.000055  max_mem: 5290M
# [01/31 09:42:39 d2.utils.events]:  eta: 0:46:55  iter: 239  total_loss: 0.760  loss_cls: 0.357  loss_box_reg: 0.281  loss_rpn_cls: 0.059  loss_rpn_loc: 0.057  time: 1.0145  data_time: 0.0371  lr: 0.000060  max_mem: 5290M
# [01/31 09:42:59 d2.utils.events]:  eta: 0:46:28  iter: 259  total_loss: 0.699  loss_cls: 0.340  loss_box_reg: 0.236  loss_rpn_cls: 0.078  loss_rpn_loc: 0.061  time: 1.0128  data_time: 0.0381  lr: 0.000065  max_mem: 5290M
# [01/31 09:43:19 d2.utils.events]:  eta: 0:45:53  iter: 279  total_loss: 0.716  loss_cls: 0.345  loss_box_reg: 0.265  loss_rpn_cls: 0.050  loss_rpn_loc: 0.040  time: 1.0098  data_time: 0.0357  lr: 0.000070  max_mem: 5290M
# [01/31 09:43:38 d2.utils.events]:  eta: 0:45:28  iter: 299  total_loss: 0.829  loss_cls: 0.396  loss_box_reg: 0.315  loss_rpn_cls: 0.057  loss_rpn_loc: 0.046  time: 1.0075  data_time: 0.0370  lr: 0.000075  max_mem: 5290M
# [01/31 09:44:00 d2.utils.events]:  eta: 0:45:24  iter: 319  total_loss: 0.834  loss_cls: 0.402  loss_box_reg: 0.348  loss_rpn_cls: 0.049  loss_rpn_loc: 0.046  time: 1.0120  data_time: 0.0392  lr: 0.000080  max_mem: 5290M
# [01/31 09:44:20 d2.utils.events]:  eta: 0:45:08  iter: 339  total_loss: 0.879  loss_cls: 0.421  loss_box_reg: 0.344  loss_rpn_cls: 0.029  loss_rpn_loc: 0.051  time: 1.0131  data_time: 0.0368  lr: 0.000085  max_mem: 5290M
# [01/31 09:44:41 d2.utils.events]:  eta: 0:44:51  iter: 359  total_loss: 0.917  loss_cls: 0.439  loss_box_reg: 0.380  loss_rpn_cls: 0.039  loss_rpn_loc: 0.048  time: 1.0149  data_time: 0.0394  lr: 0.000090  max_mem: 5290M
# [01/31 09:45:02 d2.utils.events]:  eta: 0:44:34  iter: 379  total_loss: 0.820  loss_cls: 0.390  loss_box_reg: 0.333  loss_rpn_cls: 0.031  loss_rpn_loc: 0.036  time: 1.0164  data_time: 0.0375  lr: 0.000095  max_mem: 5290M
# [01/31 09:45:23 d2.utils.events]:  eta: 0:44:17  iter: 399  total_loss: 0.854  loss_cls: 0.413  loss_box_reg: 0.380  loss_rpn_cls: 0.030  loss_rpn_loc: 0.036  time: 1.0177  data_time: 0.0377  lr: 0.000100  max_mem: 5290M
# [01/31 09:45:43 d2.utils.events]:  eta: 0:43:54  iter: 419  total_loss: 0.821  loss_cls: 0.386  loss_box_reg: 0.353  loss_rpn_cls: 0.028  loss_rpn_loc: 0.042  time: 1.0173  data_time: 0.0374  lr: 0.000105  max_mem: 5290M
# [01/31 09:46:04 d2.utils.events]:  eta: 0:43:35  iter: 439  total_loss: 0.876  loss_cls: 0.411  loss_box_reg: 0.385  loss_rpn_cls: 0.038  loss_rpn_loc: 0.043  time: 1.0175  data_time: 0.0368  lr: 0.000110  max_mem: 5290M
# [01/31 09:46:24 d2.utils.events]:  eta: 0:43:14  iter: 459  total_loss: 0.888  loss_cls: 0.410  loss_box_reg: 0.372  loss_rpn_cls: 0.033  loss_rpn_loc: 0.039  time: 1.0170  data_time: 0.0374  lr: 0.000115  max_mem: 5290M
# [01/31 09:46:44 d2.utils.events]:  eta: 0:42:56  iter: 479  total_loss: 0.902  loss_cls: 0.430  loss_box_reg: 0.396  loss_rpn_cls: 0.024  loss_rpn_loc: 0.035  time: 1.0176  data_time: 0.0387  lr: 0.000120  max_mem: 5290M
# [01/31 09:47:05 d2.utils.events]:  eta: 0:42:34  iter: 499  total_loss: 0.798  loss_cls: 0.379  loss_box_reg: 0.358  loss_rpn_cls: 0.026  loss_rpn_loc: 0.035  time: 1.0174  data_time: 0.0368  lr: 0.000125  max_mem: 5290M
# [01/31 09:47:25 d2.utils.events]:  eta: 0:42:17  iter: 519  total_loss: 0.840  loss_cls: 0.387  loss_box_reg: 0.373  loss_rpn_cls: 0.032  loss_rpn_loc: 0.039  time: 1.0177  data_time: 0.0373  lr: 0.000130  max_mem: 5290M
# [01/31 09:47:45 d2.utils.events]:  eta: 0:41:53  iter: 539  total_loss: 0.813  loss_cls: 0.370  loss_box_reg: 0.377  loss_rpn_cls: 0.019  loss_rpn_loc: 0.034  time: 1.0171  data_time: 0.0379  lr: 0.000135  max_mem: 5290M
# [01/31 09:48:06 d2.utils.events]:  eta: 0:41:36  iter: 559  total_loss: 0.813  loss_cls: 0.380  loss_box_reg: 0.387  loss_rpn_cls: 0.021  loss_rpn_loc: 0.038  time: 1.0174  data_time: 0.0390  lr: 0.000140  max_mem: 5290M
# [01/31 09:48:26 d2.utils.events]:  eta: 0:41:17  iter: 579  total_loss: 0.852  loss_cls: 0.404  loss_box_reg: 0.394  loss_rpn_cls: 0.014  loss_rpn_loc: 0.034  time: 1.0178  data_time: 0.0381  lr: 0.000145  max_mem: 5290M
# [01/31 09:48:46 d2.utils.events]:  eta: 0:40:51  iter: 599  total_loss: 0.793  loss_cls: 0.362  loss_box_reg: 0.364  loss_rpn_cls: 0.014  loss_rpn_loc: 0.029  time: 1.0160  data_time: 0.0376  lr: 0.000150  max_mem: 5290M
# [01/31 09:49:05 d2.utils.events]:  eta: 0:40:29  iter: 619  total_loss: 0.802  loss_cls: 0.377  loss_box_reg: 0.384  loss_rpn_cls: 0.014  loss_rpn_loc: 0.032  time: 1.0150  data_time: 0.0380  lr: 0.000155  max_mem: 5290M
# [01/31 09:49:26 d2.utils.events]:  eta: 0:40:09  iter: 639  total_loss: 0.763  loss_cls: 0.356  loss_box_reg: 0.374  loss_rpn_cls: 0.013  loss_rpn_loc: 0.030  time: 1.0157  data_time: 0.0381  lr: 0.000160  max_mem: 5290M
# [01/31 09:49:46 d2.utils.events]:  eta: 0:39:48  iter: 659  total_loss: 0.785  loss_cls: 0.356  loss_box_reg: 0.370  loss_rpn_cls: 0.016  loss_rpn_loc: 0.032  time: 1.0157  data_time: 0.0392  lr: 0.000165  max_mem: 5290M
# [01/31 09:50:06 d2.utils.events]:  eta: 0:39:28  iter: 679  total_loss: 0.834  loss_cls: 0.385  loss_box_reg: 0.402  loss_rpn_cls: 0.012  loss_rpn_loc: 0.032  time: 1.0152  data_time: 0.0378  lr: 0.000170  max_mem: 5290M
# [01/31 09:50:27 d2.utils.events]:  eta: 0:39:06  iter: 699  total_loss: 0.782  loss_cls: 0.344  loss_box_reg: 0.371  loss_rpn_cls: 0.015  loss_rpn_loc: 0.035  time: 1.0153  data_time: 0.0383  lr: 0.000175  max_mem: 5290M
# [01/31 09:50:47 d2.utils.events]:  eta: 0:38:45  iter: 719  total_loss: 0.790  loss_cls: 0.351  loss_box_reg: 0.378  loss_rpn_cls: 0.019  loss_rpn_loc: 0.029  time: 1.0151  data_time: 0.0398  lr: 0.000180  max_mem: 5290M
# [01/31 09:51:07 d2.utils.events]:  eta: 0:38:22  iter: 739  total_loss: 0.699  loss_cls: 0.313  loss_box_reg: 0.354  loss_rpn_cls: 0.013  loss_rpn_loc: 0.030  time: 1.0146  data_time: 0.0390  lr: 0.000185  max_mem: 5290M
# [01/31 09:51:28 d2.utils.events]:  eta: 0:38:04  iter: 759  total_loss: 0.752  loss_cls: 0.335  loss_box_reg: 0.365  loss_rpn_cls: 0.016  loss_rpn_loc: 0.032  time: 1.0150  data_time: 0.0386  lr: 0.000190  max_mem: 5290M
# [01/31 09:51:48 d2.utils.events]:  eta: 0:37:44  iter: 779  total_loss: 0.754  loss_cls: 0.336  loss_box_reg: 0.393  loss_rpn_cls: 0.008  loss_rpn_loc: 0.025  time: 1.0154  data_time: 0.0390  lr: 0.000195  max_mem: 5290M
# [01/31 09:52:09 d2.utils.events]:  eta: 0:37:26  iter: 799  total_loss: 0.816  loss_cls: 0.356  loss_box_reg: 0.401  loss_rpn_cls: 0.013  loss_rpn_loc: 0.035  time: 1.0162  data_time: 0.0386  lr: 0.000200  max_mem: 5290M
# [01/31 09:52:30 d2.utils.events]:  eta: 0:37:08  iter: 819  total_loss: 0.714  loss_cls: 0.324  loss_box_reg: 0.354  loss_rpn_cls: 0.009  loss_rpn_loc: 0.025  time: 1.0170  data_time: 0.0389  lr: 0.000205  max_mem: 5290M
# [01/31 09:52:51 d2.utils.events]:  eta: 0:36:49  iter: 839  total_loss: 0.765  loss_cls: 0.347  loss_box_reg: 0.371  loss_rpn_cls: 0.009  loss_rpn_loc: 0.027  time: 1.0173  data_time: 0.0388  lr: 0.000210  max_mem: 5290M
# [01/31 09:53:11 d2.utils.events]:  eta: 0:36:27  iter: 859  total_loss: 0.645  loss_cls: 0.288  loss_box_reg: 0.317  loss_rpn_cls: 0.010  loss_rpn_loc: 0.026  time: 1.0170  data_time: 0.0394  lr: 0.000215  max_mem: 5290M
# [01/31 09:53:31 d2.utils.events]:  eta: 0:36:06  iter: 879  total_loss: 0.633  loss_cls: 0.291  loss_box_reg: 0.323  loss_rpn_cls: 0.013  loss_rpn_loc: 0.026  time: 1.0172  data_time: 0.0392  lr: 0.000220  max_mem: 5290M
# [01/31 09:53:52 d2.utils.events]:  eta: 0:35:46  iter: 899  total_loss: 0.640  loss_cls: 0.284  loss_box_reg: 0.299  loss_rpn_cls: 0.008  loss_rpn_loc: 0.029  time: 1.0171  data_time: 0.0374  lr: 0.000225  max_mem: 5290M
# [01/31 09:54:13 d2.utils.events]:  eta: 0:35:29  iter: 919  total_loss: 0.609  loss_cls: 0.276  loss_box_reg: 0.310  loss_rpn_cls: 0.005  loss_rpn_loc: 0.023  time: 1.0178  data_time: 0.0397  lr: 0.000230  max_mem: 5290M
# [01/31 09:54:33 d2.utils.events]:  eta: 0:35:07  iter: 939  total_loss: 0.637  loss_cls: 0.309  loss_box_reg: 0.279  loss_rpn_cls: 0.010  loss_rpn_loc: 0.029  time: 1.0182  data_time: 0.0398  lr: 0.000235  max_mem: 5290M
# [01/31 09:54:54 d2.utils.events]:  eta: 0:34:45  iter: 959  total_loss: 0.544  loss_cls: 0.262  loss_box_reg: 0.260  loss_rpn_cls: 0.009  loss_rpn_loc: 0.024  time: 1.0181  data_time: 0.0383  lr: 0.000240  max_mem: 5290M
# [01/31 09:55:14 d2.utils.events]:  eta: 0:34:24  iter: 979  total_loss: 0.592  loss_cls: 0.278  loss_box_reg: 0.282  loss_rpn_cls: 0.004  loss_rpn_loc: 0.025  time: 1.0180  data_time: 0.0376  lr: 0.000245  max_mem: 5290M
# [01/31 09:55:34 d2.utils.events]:  eta: 0:34:03  iter: 999  total_loss: 0.530  loss_cls: 0.247  loss_box_reg: 0.252  loss_rpn_cls: 0.005  loss_rpn_loc: 0.028  time: 1.0177  data_time: 0.0376  lr: 0.000250  max_mem: 5290M
# [01/31 09:55:55 d2.utils.events]:  eta: 0:33:48  iter: 1019  total_loss: 0.542  loss_cls: 0.246  loss_box_reg: 0.261  loss_rpn_cls: 0.010  loss_rpn_loc: 0.028  time: 1.0181  data_time: 0.0396  lr: 0.000250  max_mem: 5290M
# [01/31 09:56:15 d2.utils.events]:  eta: 0:33:28  iter: 1039  total_loss: 0.518  loss_cls: 0.235  loss_box_reg: 0.231  loss_rpn_cls: 0.010  loss_rpn_loc: 0.024  time: 1.0177  data_time: 0.0384  lr: 0.000250  max_mem: 5290M
# [01/31 09:56:35 d2.utils.events]:  eta: 0:33:07  iter: 1059  total_loss: 0.517  loss_cls: 0.237  loss_box_reg: 0.245  loss_rpn_cls: 0.007  loss_rpn_loc: 0.026  time: 1.0176  data_time: 0.0375  lr: 0.000250  max_mem: 5290M
# [01/31 09:56:55 d2.utils.events]:  eta: 0:32:45  iter: 1079  total_loss: 0.575  loss_cls: 0.257  loss_box_reg: 0.261  loss_rpn_cls: 0.005  loss_rpn_loc: 0.033  time: 1.0171  data_time: 0.0377  lr: 0.000250  max_mem: 5290M
# [01/31 09:57:15 d2.utils.events]:  eta: 0:32:23  iter: 1099  total_loss: 0.518  loss_cls: 0.237  loss_box_reg: 0.251  loss_rpn_cls: 0.004  loss_rpn_loc: 0.025  time: 1.0169  data_time: 0.0378  lr: 0.000250  max_mem: 5290M
# [01/31 09:57:34 d2.utils.events]:  eta: 0:32:01  iter: 1119  total_loss: 0.508  loss_cls: 0.233  loss_box_reg: 0.242  loss_rpn_cls: 0.007  loss_rpn_loc: 0.026  time: 1.0159  data_time: 0.0367  lr: 0.000250  max_mem: 5290M
# [01/31 09:57:54 d2.utils.events]:  eta: 0:31:41  iter: 1139  total_loss: 0.456  loss_cls: 0.204  loss_box_reg: 0.215  loss_rpn_cls: 0.004  loss_rpn_loc: 0.022  time: 1.0159  data_time: 0.0374  lr: 0.000250  max_mem: 5290M
# [01/31 09:58:15 d2.utils.events]:  eta: 0:31:20  iter: 1159  total_loss: 0.560  loss_cls: 0.255  loss_box_reg: 0.273  loss_rpn_cls: 0.006  loss_rpn_loc: 0.027  time: 1.0157  data_time: 0.0379  lr: 0.000250  max_mem: 5290M
# [01/31 09:58:34 d2.utils.events]:  eta: 0:31:00  iter: 1179  total_loss: 0.521  loss_cls: 0.226  loss_box_reg: 0.252  loss_rpn_cls: 0.010  loss_rpn_loc: 0.027  time: 1.0153  data_time: 0.0389  lr: 0.000250  max_mem: 5290M
# [01/31 09:58:55 d2.utils.events]:  eta: 0:30:45  iter: 1199  total_loss: 0.469  loss_cls: 0.199  loss_box_reg: 0.237  loss_rpn_cls: 0.005  loss_rpn_loc: 0.024  time: 1.0158  data_time: 0.0386  lr: 0.000250  max_mem: 5290M
# [01/31 09:59:17 d2.utils.events]:  eta: 0:30:33  iter: 1219  total_loss: 0.429  loss_cls: 0.189  loss_box_reg: 0.227  loss_rpn_cls: 0.005  loss_rpn_loc: 0.025  time: 1.0167  data_time: 0.0397  lr: 0.000250  max_mem: 5290M
# [01/31 09:59:36 d2.utils.events]:  eta: 0:30:03  iter: 1239  total_loss: 0.437  loss_cls: 0.175  loss_box_reg: 0.210  loss_rpn_cls: 0.003  loss_rpn_loc: 0.022  time: 1.0159  data_time: 0.0380  lr: 0.000250  max_mem: 5290M
# [01/31 09:59:55 d2.utils.events]:  eta: 0:29:41  iter: 1259  total_loss: 0.464  loss_cls: 0.172  loss_box_reg: 0.232  loss_rpn_cls: 0.004  loss_rpn_loc: 0.024  time: 1.0149  data_time: 0.0365  lr: 0.000250  max_mem: 5290M
# [01/31 10:00:15 d2.utils.events]:  eta: 0:29:22  iter: 1279  total_loss: 0.451  loss_cls: 0.193  loss_box_reg: 0.215  loss_rpn_cls: 0.007  loss_rpn_loc: 0.024  time: 1.0144  data_time: 0.0362  lr: 0.000250  max_mem: 5290M
# [01/31 10:00:35 d2.utils.events]:  eta: 0:29:14  iter: 1299  total_loss: 0.429  loss_cls: 0.180  loss_box_reg: 0.220  loss_rpn_cls: 0.005  loss_rpn_loc: 0.023  time: 1.0146  data_time: 0.0372  lr: 0.000250  max_mem: 5290M
# [01/31 10:00:56 d2.utils.events]:  eta: 0:28:43  iter: 1319  total_loss: 0.412  loss_cls: 0.172  loss_box_reg: 0.212  loss_rpn_cls: 0.004  loss_rpn_loc: 0.023  time: 1.0145  data_time: 0.0372  lr: 0.000250  max_mem: 5290M
# [01/31 10:01:16 d2.utils.events]:  eta: 0:28:21  iter: 1339  total_loss: 0.507  loss_cls: 0.217  loss_box_reg: 0.243  loss_rpn_cls: 0.005  loss_rpn_loc: 0.025  time: 1.0148  data_time: 0.0385  lr: 0.000250  max_mem: 5290M
# [01/31 10:01:36 d2.utils.events]:  eta: 0:27:59  iter: 1359  total_loss: 0.413  loss_cls: 0.177  loss_box_reg: 0.208  loss_rpn_cls: 0.005  loss_rpn_loc: 0.022  time: 1.0147  data_time: 0.0389  lr: 0.000250  max_mem: 5290M
# [01/31 10:01:57 d2.utils.events]:  eta: 0:27:37  iter: 1379  total_loss: 0.366  loss_cls: 0.152  loss_box_reg: 0.200  loss_rpn_cls: 0.006  loss_rpn_loc: 0.021  time: 1.0148  data_time: 0.0391  lr: 0.000250  max_mem: 5290M
# [01/31 10:02:17 d2.utils.events]:  eta: 0:27:14  iter: 1399  total_loss: 0.358  loss_cls: 0.131  loss_box_reg: 0.204  loss_rpn_cls: 0.004  loss_rpn_loc: 0.023  time: 1.0146  data_time: 0.0382  lr: 0.000250  max_mem: 5290M
# [01/31 10:02:39 d2.utils.events]:  eta: 0:26:58  iter: 1419  total_loss: 0.389  loss_cls: 0.175  loss_box_reg: 0.210  loss_rpn_cls: 0.006  loss_rpn_loc: 0.022  time: 1.0155  data_time: 0.0391  lr: 0.000250  max_mem: 5290M
# [01/31 10:02:59 d2.utils.events]:  eta: 0:26:38  iter: 1439  total_loss: 0.353  loss_cls: 0.156  loss_box_reg: 0.188  loss_rpn_cls: 0.002  loss_rpn_loc: 0.017  time: 1.0154  data_time: 0.0381  lr: 0.000250  max_mem: 5290M
# [01/31 10:03:20 d2.utils.events]:  eta: 0:26:20  iter: 1459  total_loss: 0.482  loss_cls: 0.182  loss_box_reg: 0.241  loss_rpn_cls: 0.008  loss_rpn_loc: 0.024  time: 1.0157  data_time: 0.0396  lr: 0.000250  max_mem: 5290M
# [01/31 10:03:40 d2.utils.events]:  eta: 0:25:59  iter: 1479  total_loss: 0.386  loss_cls: 0.146  loss_box_reg: 0.207  loss_rpn_cls: 0.004  loss_rpn_loc: 0.024  time: 1.0159  data_time: 0.0388  lr: 0.000250  max_mem: 5290M
# [01/31 10:04:01 d2.utils.events]:  eta: 0:25:44  iter: 1499  total_loss: 0.446  loss_cls: 0.178  loss_box_reg: 0.235  loss_rpn_cls: 0.002  loss_rpn_loc: 0.027  time: 1.0161  data_time: 0.0389  lr: 0.000250  max_mem: 5290M
# [01/31 10:04:21 d2.utils.events]:  eta: 0:25:20  iter: 1519  total_loss: 0.354  loss_cls: 0.121  loss_box_reg: 0.196  loss_rpn_cls: 0.004  loss_rpn_loc: 0.020  time: 1.0161  data_time: 0.0371  lr: 0.000250  max_mem: 5290M
# [01/31 10:04:42 d2.utils.events]:  eta: 0:25:06  iter: 1539  total_loss: 0.376  loss_cls: 0.140  loss_box_reg: 0.194  loss_rpn_cls: 0.003  loss_rpn_loc: 0.022  time: 1.0162  data_time: 0.0381  lr: 0.000250  max_mem: 5290M
# [01/31 10:05:02 d2.utils.events]:  eta: 0:24:41  iter: 1559  total_loss: 0.413  loss_cls: 0.154  loss_box_reg: 0.208  loss_rpn_cls: 0.003  loss_rpn_loc: 0.024  time: 1.0164  data_time: 0.0419  lr: 0.000250  max_mem: 5290M
# [01/31 10:05:23 d2.utils.events]:  eta: 0:24:20  iter: 1579  total_loss: 0.352  loss_cls: 0.138  loss_box_reg: 0.190  loss_rpn_cls: 0.003  loss_rpn_loc: 0.021  time: 1.0166  data_time: 0.0388  lr: 0.000250  max_mem: 5290M
# [01/31 10:05:44 d2.utils.events]:  eta: 0:24:08  iter: 1599  total_loss: 0.341  loss_cls: 0.131  loss_box_reg: 0.187  loss_rpn_cls: 0.003  loss_rpn_loc: 0.019  time: 1.0172  data_time: 0.0407  lr: 0.000250  max_mem: 5290M
# [01/31 10:06:05 d2.utils.events]:  eta: 0:23:53  iter: 1619  total_loss: 0.419  loss_cls: 0.151  loss_box_reg: 0.212  loss_rpn_cls: 0.003  loss_rpn_loc: 0.024  time: 1.0174  data_time: 0.0395  lr: 0.000250  max_mem: 5290M
# [01/31 10:06:25 d2.utils.events]:  eta: 0:23:28  iter: 1639  total_loss: 0.397  loss_cls: 0.155  loss_box_reg: 0.217  loss_rpn_cls: 0.001  loss_rpn_loc: 0.026  time: 1.0173  data_time: 0.0385  lr: 0.000250  max_mem: 5290M
# [01/31 10:06:46 d2.utils.events]:  eta: 0:23:11  iter: 1659  total_loss: 0.415  loss_cls: 0.162  loss_box_reg: 0.226  loss_rpn_cls: 0.002  loss_rpn_loc: 0.021  time: 1.0175  data_time: 0.0400  lr: 0.000250  max_mem: 5290M
# [01/31 10:07:07 d2.utils.events]:  eta: 0:22:51  iter: 1679  total_loss: 0.331  loss_cls: 0.137  loss_box_reg: 0.184  loss_rpn_cls: 0.002  loss_rpn_loc: 0.018  time: 1.0178  data_time: 0.0414  lr: 0.000250  max_mem: 5290M
# [01/31 10:07:27 d2.utils.events]:  eta: 0:22:31  iter: 1699  total_loss: 0.398  loss_cls: 0.151  loss_box_reg: 0.209  loss_rpn_cls: 0.003  loss_rpn_loc: 0.025  time: 1.0178  data_time: 0.0382  lr: 0.000250  max_mem: 5290M
# [01/31 10:07:47 d2.utils.events]:  eta: 0:22:11  iter: 1719  total_loss: 0.323  loss_cls: 0.126  loss_box_reg: 0.183  loss_rpn_cls: 0.005  loss_rpn_loc: 0.020  time: 1.0177  data_time: 0.0373  lr: 0.000250  max_mem: 5290M
# [01/31 10:08:08 d2.utils.events]:  eta: 0:21:52  iter: 1739  total_loss: 0.374  loss_cls: 0.134  loss_box_reg: 0.202  loss_rpn_cls: 0.004  loss_rpn_loc: 0.022  time: 1.0178  data_time: 0.0378  lr: 0.000250  max_mem: 5290M
# [01/31 10:08:28 d2.utils.events]:  eta: 0:21:31  iter: 1759  total_loss: 0.392  loss_cls: 0.135  loss_box_reg: 0.211  loss_rpn_cls: 0.004  loss_rpn_loc: 0.026  time: 1.0180  data_time: 0.0367  lr: 0.000250  max_mem: 5290M
# [01/31 10:08:49 d2.utils.events]:  eta: 0:21:11  iter: 1779  total_loss: 0.387  loss_cls: 0.154  loss_box_reg: 0.205  loss_rpn_cls: 0.003  loss_rpn_loc: 0.024  time: 1.0181  data_time: 0.0378  lr: 0.000250  max_mem: 5290M
# [01/31 10:09:10 d2.utils.events]:  eta: 0:20:50  iter: 1799  total_loss: 0.361  loss_cls: 0.147  loss_box_reg: 0.188  loss_rpn_cls: 0.004  loss_rpn_loc: 0.020  time: 1.0184  data_time: 0.0370  lr: 0.000250  max_mem: 5290M
# [01/31 10:09:31 d2.utils.events]:  eta: 0:20:29  iter: 1819  total_loss: 0.331  loss_cls: 0.124  loss_box_reg: 0.176  loss_rpn_cls: 0.002  loss_rpn_loc: 0.021  time: 1.0188  data_time: 0.0405  lr: 0.000250  max_mem: 5290M
# [01/31 10:09:51 d2.utils.events]:  eta: 0:20:08  iter: 1839  total_loss: 0.318  loss_cls: 0.109  loss_box_reg: 0.186  loss_rpn_cls: 0.002  loss_rpn_loc: 0.019  time: 1.0187  data_time: 0.0384  lr: 0.000250  max_mem: 5290M
# [01/31 10:10:12 d2.utils.events]:  eta: 0:19:48  iter: 1859  total_loss: 0.375  loss_cls: 0.143  loss_box_reg: 0.204  loss_rpn_cls: 0.002  loss_rpn_loc: 0.019  time: 1.0188  data_time: 0.0376  lr: 0.000250  max_mem: 5290M
# [01/31 10:10:33 d2.utils.events]:  eta: 0:19:28  iter: 1879  total_loss: 0.379  loss_cls: 0.133  loss_box_reg: 0.219  loss_rpn_cls: 0.002  loss_rpn_loc: 0.021  time: 1.0192  data_time: 0.0387  lr: 0.000250  max_mem: 5290M
# [01/31 10:10:53 d2.utils.events]:  eta: 0:19:06  iter: 1899  total_loss: 0.388  loss_cls: 0.142  loss_box_reg: 0.199  loss_rpn_cls: 0.003  loss_rpn_loc: 0.018  time: 1.0191  data_time: 0.0375  lr: 0.000250  max_mem: 5290M
# [01/31 10:11:14 d2.utils.events]:  eta: 0:18:45  iter: 1919  total_loss: 0.358  loss_cls: 0.146  loss_box_reg: 0.193  loss_rpn_cls: 0.003  loss_rpn_loc: 0.024  time: 1.0193  data_time: 0.0383  lr: 0.000250  max_mem: 5290M
# [01/31 10:11:35 d2.utils.events]:  eta: 0:18:26  iter: 1939  total_loss: 0.351  loss_cls: 0.133  loss_box_reg: 0.195  loss_rpn_cls: 0.003  loss_rpn_loc: 0.021  time: 1.0199  data_time: 0.0367  lr: 0.000250  max_mem: 5290M
# [01/31 10:11:56 d2.utils.events]:  eta: 0:18:06  iter: 1959  total_loss: 0.359  loss_cls: 0.134  loss_box_reg: 0.188  loss_rpn_cls: 0.002  loss_rpn_loc: 0.019  time: 1.0201  data_time: 0.0380  lr: 0.000250  max_mem: 5290M
# [01/31 10:12:18 d2.utils.events]:  eta: 0:17:45  iter: 1979  total_loss: 0.357  loss_cls: 0.141  loss_box_reg: 0.179  loss_rpn_cls: 0.004  loss_rpn_loc: 0.021  time: 1.0206  data_time: 0.0383  lr: 0.000250  max_mem: 5290M
# [01/31 10:12:38 d2.utils.events]:  eta: 0:17:25  iter: 1999  total_loss: 0.365  loss_cls: 0.130  loss_box_reg: 0.205  loss_rpn_cls: 0.002  loss_rpn_loc: 0.019  time: 1.0206  data_time: 0.0362  lr: 0.000250  max_mem: 5290M
# [01/31 10:12:59 d2.utils.events]:  eta: 0:17:04  iter: 2019  total_loss: 0.363  loss_cls: 0.145  loss_box_reg: 0.207  loss_rpn_cls: 0.003  loss_rpn_loc: 0.023  time: 1.0210  data_time: 0.0387  lr: 0.000250  max_mem: 5290M
# [01/31 10:13:20 d2.utils.events]:  eta: 0:16:44  iter: 2039  total_loss: 0.355  loss_cls: 0.122  loss_box_reg: 0.202  loss_rpn_cls: 0.003  loss_rpn_loc: 0.021  time: 1.0211  data_time: 0.0375  lr: 0.000250  max_mem: 5290M
# [01/31 10:13:41 d2.utils.events]:  eta: 0:16:23  iter: 2059  total_loss: 0.343  loss_cls: 0.128  loss_box_reg: 0.208  loss_rpn_cls: 0.002  loss_rpn_loc: 0.023  time: 1.0213  data_time: 0.0390  lr: 0.000250  max_mem: 5290M
# [01/31 10:14:02 d2.utils.events]:  eta: 0:16:02  iter: 2079  total_loss: 0.329  loss_cls: 0.119  loss_box_reg: 0.202  loss_rpn_cls: 0.001  loss_rpn_loc: 0.018  time: 1.0214  data_time: 0.0390  lr: 0.000250  max_mem: 5290M
# [01/31 10:14:22 d2.utils.events]:  eta: 0:15:41  iter: 2099  total_loss: 0.337  loss_cls: 0.124  loss_box_reg: 0.191  loss_rpn_cls: 0.003  loss_rpn_loc: 0.019  time: 1.0215  data_time: 0.0372  lr: 0.000250  max_mem: 5290M
# [01/31 10:14:43 d2.utils.events]:  eta: 0:15:20  iter: 2119  total_loss: 0.345  loss_cls: 0.138  loss_box_reg: 0.172  loss_rpn_cls: 0.003  loss_rpn_loc: 0.020  time: 1.0219  data_time: 0.0388  lr: 0.000250  max_mem: 5290M
# [01/31 10:15:04 d2.utils.events]:  eta: 0:15:00  iter: 2139  total_loss: 0.331  loss_cls: 0.120  loss_box_reg: 0.190  loss_rpn_cls: 0.001  loss_rpn_loc: 0.021  time: 1.0219  data_time: 0.0409  lr: 0.000250  max_mem: 5290M
# [01/31 10:15:23 d2.utils.events]:  eta: 0:14:38  iter: 2159  total_loss: 0.303  loss_cls: 0.102  loss_box_reg: 0.182  loss_rpn_cls: 0.002  loss_rpn_loc: 0.020  time: 1.0214  data_time: 0.0357  lr: 0.000250  max_mem: 5290M
# [01/31 10:15:44 d2.utils.events]:  eta: 0:14:18  iter: 2179  total_loss: 0.374  loss_cls: 0.132  loss_box_reg: 0.202  loss_rpn_cls: 0.002  loss_rpn_loc: 0.022  time: 1.0216  data_time: 0.0370  lr: 0.000250  max_mem: 5290M
# [01/31 10:16:05 d2.utils.events]:  eta: 0:13:57  iter: 2199  total_loss: 0.317  loss_cls: 0.126  loss_box_reg: 0.178  loss_rpn_cls: 0.004  loss_rpn_loc: 0.020  time: 1.0216  data_time: 0.0374  lr: 0.000250  max_mem: 5290M
# [01/31 10:16:26 d2.utils.events]:  eta: 0:13:36  iter: 2219  total_loss: 0.317  loss_cls: 0.119  loss_box_reg: 0.172  loss_rpn_cls: 0.002  loss_rpn_loc: 0.018  time: 1.0221  data_time: 0.0383  lr: 0.000250  max_mem: 5290M
# [01/31 10:16:48 d2.utils.events]:  eta: 0:13:15  iter: 2239  total_loss: 0.284  loss_cls: 0.112  loss_box_reg: 0.163  loss_rpn_cls: 0.002  loss_rpn_loc: 0.016  time: 1.0225  data_time: 0.0383  lr: 0.000250  max_mem: 5290M
# [01/31 10:17:08 d2.utils.events]:  eta: 0:12:55  iter: 2259  total_loss: 0.299  loss_cls: 0.105  loss_box_reg: 0.173  loss_rpn_cls: 0.002  loss_rpn_loc: 0.018  time: 1.0226  data_time: 0.0372  lr: 0.000250  max_mem: 5290M
# [01/31 10:17:29 d2.utils.events]:  eta: 0:12:34  iter: 2279  total_loss: 0.354  loss_cls: 0.125  loss_box_reg: 0.198  loss_rpn_cls: 0.002  loss_rpn_loc: 0.020  time: 1.0227  data_time: 0.0370  lr: 0.000250  max_mem: 5290M
# [01/31 10:17:49 d2.utils.events]:  eta: 0:12:13  iter: 2299  total_loss: 0.319  loss_cls: 0.115  loss_box_reg: 0.190  loss_rpn_cls: 0.002  loss_rpn_loc: 0.016  time: 1.0227  data_time: 0.0366  lr: 0.000250  max_mem: 5290M
# [01/31 10:18:09 d2.utils.events]:  eta: 0:11:52  iter: 2319  total_loss: 0.327  loss_cls: 0.126  loss_box_reg: 0.186  loss_rpn_cls: 0.001  loss_rpn_loc: 0.016  time: 1.0224  data_time: 0.0366  lr: 0.000250  max_mem: 5290M
# [01/31 10:18:29 d2.utils.events]:  eta: 0:11:31  iter: 2339  total_loss: 0.312  loss_cls: 0.113  loss_box_reg: 0.169  loss_rpn_cls: 0.001  loss_rpn_loc: 0.018  time: 1.0223  data_time: 0.0351  lr: 0.000250  max_mem: 5290M
# [01/31 10:18:50 d2.utils.events]:  eta: 0:11:10  iter: 2359  total_loss: 0.374  loss_cls: 0.124  loss_box_reg: 0.202  loss_rpn_cls: 0.001  loss_rpn_loc: 0.019  time: 1.0222  data_time: 0.0384  lr: 0.000250  max_mem: 5290M
# [01/31 10:19:09 d2.utils.events]:  eta: 0:10:49  iter: 2379  total_loss: 0.349  loss_cls: 0.115  loss_box_reg: 0.196  loss_rpn_cls: 0.001  loss_rpn_loc: 0.021  time: 1.0219  data_time: 0.0360  lr: 0.000250  max_mem: 5290M
# [01/31 10:19:30 d2.utils.events]:  eta: 0:10:28  iter: 2399  total_loss: 0.347  loss_cls: 0.120  loss_box_reg: 0.187  loss_rpn_cls: 0.002  loss_rpn_loc: 0.020  time: 1.0220  data_time: 0.0375  lr: 0.000250  max_mem: 5290M
# [01/31 10:19:51 d2.utils.events]:  eta: 0:10:07  iter: 2419  total_loss: 0.316  loss_cls: 0.117  loss_box_reg: 0.179  loss_rpn_cls: 0.001  loss_rpn_loc: 0.018  time: 1.0223  data_time: 0.0379  lr: 0.000250  max_mem: 5290M
# [01/31 10:20:12 d2.utils.events]:  eta: 0:09:46  iter: 2439  total_loss: 0.304  loss_cls: 0.108  loss_box_reg: 0.170  loss_rpn_cls: 0.001  loss_rpn_loc: 0.017  time: 1.0224  data_time: 0.0391  lr: 0.000250  max_mem: 5290M
# [01/31 10:20:33 d2.utils.events]:  eta: 0:09:25  iter: 2459  total_loss: 0.326  loss_cls: 0.105  loss_box_reg: 0.182  loss_rpn_cls: 0.001  loss_rpn_loc: 0.018  time: 1.0225  data_time: 0.0368  lr: 0.000250  max_mem: 5290M
# [01/31 10:20:54 d2.utils.events]:  eta: 0:09:05  iter: 2479  total_loss: 0.329  loss_cls: 0.113  loss_box_reg: 0.189  loss_rpn_cls: 0.002  loss_rpn_loc: 0.020  time: 1.0227  data_time: 0.0385  lr: 0.000250  max_mem: 5290M
# [01/31 10:21:14 d2.utils.events]:  eta: 0:08:43  iter: 2499  total_loss: 0.311  loss_cls: 0.103  loss_box_reg: 0.180  loss_rpn_cls: 0.002  loss_rpn_loc: 0.018  time: 1.0226  data_time: 0.0368  lr: 0.000250  max_mem: 5290M
# [01/31 10:21:34 d2.utils.events]:  eta: 0:08:22  iter: 2519  total_loss: 0.331  loss_cls: 0.113  loss_box_reg: 0.186  loss_rpn_cls: 0.001  loss_rpn_loc: 0.018  time: 1.0224  data_time: 0.0366  lr: 0.000250  max_mem: 5290M
# [01/31 10:21:55 d2.utils.events]:  eta: 0:08:02  iter: 2539  total_loss: 0.297  loss_cls: 0.105  loss_box_reg: 0.161  loss_rpn_cls: 0.001  loss_rpn_loc: 0.019  time: 1.0226  data_time: 0.0383  lr: 0.000250  max_mem: 5290M
# [01/31 10:22:15 d2.utils.events]:  eta: 0:07:41  iter: 2559  total_loss: 0.285  loss_cls: 0.099  loss_box_reg: 0.171  loss_rpn_cls: 0.002  loss_rpn_loc: 0.019  time: 1.0226  data_time: 0.0372  lr: 0.000250  max_mem: 5290M
# [01/31 10:22:36 d2.utils.events]:  eta: 0:07:20  iter: 2579  total_loss: 0.314  loss_cls: 0.110  loss_box_reg: 0.185  loss_rpn_cls: 0.001  loss_rpn_loc: 0.021  time: 1.0227  data_time: 0.0369  lr: 0.000250  max_mem: 5290M
# [01/31 10:22:56 d2.utils.events]:  eta: 0:06:59  iter: 2599  total_loss: 0.325  loss_cls: 0.120  loss_box_reg: 0.186  loss_rpn_cls: 0.001  loss_rpn_loc: 0.019  time: 1.0225  data_time: 0.0367  lr: 0.000250  max_mem: 5290M
# [01/31 10:23:16 d2.utils.events]:  eta: 0:06:38  iter: 2619  total_loss: 0.288  loss_cls: 0.105  loss_box_reg: 0.164  loss_rpn_cls: 0.001  loss_rpn_loc: 0.019  time: 1.0222  data_time: 0.0373  lr: 0.000250  max_mem: 5290M
# [01/31 10:23:36 d2.utils.events]:  eta: 0:06:17  iter: 2639  total_loss: 0.307  loss_cls: 0.110  loss_box_reg: 0.168  loss_rpn_cls: 0.001  loss_rpn_loc: 0.018  time: 1.0221  data_time: 0.0366  lr: 0.000250  max_mem: 5290M
# [01/31 10:23:56 d2.utils.events]:  eta: 0:05:56  iter: 2659  total_loss: 0.323  loss_cls: 0.106  loss_box_reg: 0.191  loss_rpn_cls: 0.002  loss_rpn_loc: 0.020  time: 1.0219  data_time: 0.0366  lr: 0.000250  max_mem: 5290M
# [01/31 10:24:16 d2.utils.events]:  eta: 0:05:35  iter: 2679  total_loss: 0.312  loss_cls: 0.105  loss_box_reg: 0.187  loss_rpn_cls: 0.002  loss_rpn_loc: 0.020  time: 1.0217  data_time: 0.0384  lr: 0.000250  max_mem: 5290M
# [01/31 10:24:36 d2.utils.events]:  eta: 0:05:14  iter: 2699  total_loss: 0.302  loss_cls: 0.116  loss_box_reg: 0.164  loss_rpn_cls: 0.002  loss_rpn_loc: 0.016  time: 1.0218  data_time: 0.0370  lr: 0.000250  max_mem: 5290M
# [01/31 10:24:57 d2.utils.events]:  eta: 0:04:53  iter: 2719  total_loss: 0.277  loss_cls: 0.099  loss_box_reg: 0.163  loss_rpn_cls: 0.001  loss_rpn_loc: 0.018  time: 1.0218  data_time: 0.0377  lr: 0.000250  max_mem: 5290M
# [01/31 10:25:16 d2.utils.events]:  eta: 0:04:32  iter: 2739  total_loss: 0.328  loss_cls: 0.114  loss_box_reg: 0.185  loss_rpn_cls: 0.001  loss_rpn_loc: 0.019  time: 1.0214  data_time: 0.0366  lr: 0.000250  max_mem: 5290M
# [01/31 10:25:37 d2.utils.events]:  eta: 0:04:11  iter: 2759  total_loss: 0.349  loss_cls: 0.107  loss_box_reg: 0.199  loss_rpn_cls: 0.003  loss_rpn_loc: 0.019  time: 1.0217  data_time: 0.0392  lr: 0.000250  max_mem: 5290M
# [01/31 10:25:59 d2.utils.events]:  eta: 0:03:50  iter: 2779  total_loss: 0.323  loss_cls: 0.106  loss_box_reg: 0.179  loss_rpn_cls: 0.001  loss_rpn_loc: 0.019  time: 1.0220  data_time: 0.0400  lr: 0.000250  max_mem: 5290M
# [01/31 10:26:19 d2.utils.events]:  eta: 0:03:29  iter: 2799  total_loss: 0.319  loss_cls: 0.113  loss_box_reg: 0.183  loss_rpn_cls: 0.001  loss_rpn_loc: 0.019  time: 1.0219  data_time: 0.0369  lr: 0.000250  max_mem: 5290M
# [01/31 10:26:39 d2.utils.events]:  eta: 0:03:08  iter: 2819  total_loss: 0.296  loss_cls: 0.103  loss_box_reg: 0.171  loss_rpn_cls: 0.002  loss_rpn_loc: 0.018  time: 1.0218  data_time: 0.0372  lr: 0.000250  max_mem: 5290M
# [01/31 10:26:59 d2.utils.events]:  eta: 0:02:47  iter: 2839  total_loss: 0.310  loss_cls: 0.109  loss_box_reg: 0.185  loss_rpn_cls: 0.002  loss_rpn_loc: 0.017  time: 1.0218  data_time: 0.0375  lr: 0.000250  max_mem: 5290M
# [01/31 10:27:20 d2.utils.events]:  eta: 0:02:26  iter: 2859  total_loss: 0.292  loss_cls: 0.098  loss_box_reg: 0.171  loss_rpn_cls: 0.001  loss_rpn_loc: 0.019  time: 1.0218  data_time: 0.0370  lr: 0.000250  max_mem: 5290M
# [01/31 10:27:41 d2.utils.events]:  eta: 0:02:06  iter: 2879  total_loss: 0.300  loss_cls: 0.101  loss_box_reg: 0.168  loss_rpn_cls: 0.001  loss_rpn_loc: 0.019  time: 1.0220  data_time: 0.0366  lr: 0.000250  max_mem: 5290M
# [01/31 10:28:02 d2.utils.events]:  eta: 0:01:45  iter: 2899  total_loss: 0.296  loss_cls: 0.100  loss_box_reg: 0.170  loss_rpn_cls: 0.002  loss_rpn_loc: 0.019  time: 1.0222  data_time: 0.0390  lr: 0.000250  max_mem: 5290M
# [01/31 10:28:22 d2.utils.events]:  eta: 0:01:24  iter: 2919  total_loss: 0.273  loss_cls: 0.091  loss_box_reg: 0.159  loss_rpn_cls: 0.001  loss_rpn_loc: 0.018  time: 1.0222  data_time: 0.0354  lr: 0.000250  max_mem: 5290M
# [01/31 10:28:43 d2.utils.events]:  eta: 0:01:03  iter: 2939  total_loss: 0.290  loss_cls: 0.096  loss_box_reg: 0.160  loss_rpn_cls: 0.001  loss_rpn_loc: 0.018  time: 1.0222  data_time: 0.0361  lr: 0.000250  max_mem: 5290M
# [01/31 10:29:04 d2.utils.events]:  eta: 0:00:42  iter: 2959  total_loss: 0.304  loss_cls: 0.115  loss_box_reg: 0.171  loss_rpn_cls: 0.001  loss_rpn_loc: 0.020  time: 1.0223  data_time: 0.0377  lr: 0.000250  max_mem: 5290M
# [01/31 10:29:24 d2.utils.events]:  eta: 0:00:21  iter: 2979  total_loss: 0.283  loss_cls: 0.088  loss_box_reg: 0.166  loss_rpn_cls: 0.001  loss_rpn_loc: 0.018  time: 1.0223  data_time: 0.0371  lr: 0.000250  max_mem: 5290M
# [01/31 10:29:48 d2.utils.events]:  eta: 0:00:01  iter: 2999  total_loss: 0.311  loss_cls: 0.099  loss_box_reg: 0.179  loss_rpn_cls: 0.002  loss_rpn_loc: 0.020  time: 1.0224  data_time: 0.0392  lr: 0.000250  max_mem: 5290M
# [01/31 10:29:49 d2.engine.hooks]: Overall training speed: 2997 iterations in 0:51:05 (1.0228 s / it)
# [01/31 10:29:49 d2.engine.hooks]: Total training time: 0:51:10 (0:00:05 on hooks)

# %%
cfg.MODEL.WEIGHTS = os.path.join(cfg.OUTPUT_DIR, "model_final.pth")
cfg.MODEL.ROI_HEADS.SCORE_THRESH_TEST = 0.7   # set the testing threshold for this model
cfg.DATASETS.TEST = ("PCB_test", )
predictor = DefaultPredictor(cfg)

# %%
from detectron2.utils.visualizer import ColorMode
dataset_dicts = get_PCB_dict(test)

# %%
for d in random.sample(dataset_dicts, 3):
    im = cv2.imread(d["file_name"])
    outputs = predictor(im)
    v = Visualizer(im,
                   metadata=PCB_metadata, 
                   scale=0.8,
                   instance_mode =  ColorMode.IMAGE
        )
                   # remove the colors of unsegmented pixels
    print(outputs['instances'].pred_classes)
    print(outputs["instances"].pred_boxes)

    v = v.draw_instance_predictions(outputs["instances"].to("cpu"))
    cv2_imshow(v.get_image())
# Out:
# tensor([4, 3, 0, 0, 5, 2, 5], device='cuda:0')
# Boxes(tensor([[185.8109,  52.7067, 221.5254,  85.4870],
#         [132.2769, 316.1307, 169.7950, 349.2608],
#         [393.4436, 397.4361, 433.3918, 452.6071],
#         [495.8983, 504.7810, 527.3860, 537.8254],
#         [136.2228, 232.2282, 165.3265, 260.1822],
#         [307.7058, 231.4532, 347.4234, 260.2079],
#         [106.3260, 283.0782, 140.0311, 312.3744]], device='cuda:0'))
# tensor([4, 2, 2, 2, 5, 3], device='cuda:0')
# Boxes(tensor([[157.3743, 404.2061, 197.1308, 437.5229],
#         [258.5139, 168.5343, 295.3830, 202.0086],
#         [272.2495, 347.0393, 304.1601, 385.0892],
#         [390.7607, 140.1065, 426.3556, 167.6694],
#         [258.1510, 560.0583, 300.9344, 602.1020],
#         [506.6408, 422.6261, 541.5234, 463.1574]], device='cuda:0'))
# tensor([3, 1, 4, 5, 0, 0, 0], device='cuda:0')
# Boxes(tensor([[435.5807, 259.1520, 468.5050, 294.9539],
#         [213.0330, 141.8940, 276.0125, 177.0462],
#         [364.6862, 116.9801, 396.6633, 161.0917],
#         [442.8675, 116.5137, 478.0300, 150.7687],
#         [297.4771, 219.0593, 334.1597, 249.4045],
#         [263.2039, 402.1350, 314.2372, 456.6465],
#         [147.7739, 247.3330, 179.1048, 279.6071]], device='cuda:0'))

# %%
from detectron2.evaluation import COCOEvaluator, inference_on_dataset, LVISEvaluator
from detectron2.data import build_detection_test_loader

evaluator = COCOEvaluator("PCB_test", cfg, False, output_dir="./output/")
val_loader = build_detection_test_loader(cfg, "PCB_test")
inference_on_dataset(trainer.model, val_loader, evaluator)
# another equivalent way is to use trainer.test
# Out:
# WARNING [01/31 10:36:54 d2.evaluation.coco_evaluation]: json_file was not found in MetaDataCatalog for 'PCB_test'. Trying to convert it to COCO format ...
# [01/31 10:36:54 d2.data.datasets.coco]: Converting annotations of dataset 'PCB_test' to COCO format ...)
# [01/31 10:36:55 d2.data.datasets.coco]: Converting dataset dicts into COCO format
# [01/31 10:36:55 d2.data.datasets.coco]: Conversion finished, #images: 500, #annotations: 3140
# [01/31 10:36:55 d2.data.datasets.coco]: Caching COCO format annotations at './output/PCB_test_coco_format.json' ...
# [01/31 10:36:57 d2.data.build]: Distribution of instances among all 6 categories:
# |  category  | #instances   |  category  | #instances   |  category  | #instances   |
# |:----------:|:-------------|:----------:|:-------------|:----------:|:-------------|
# |    open    | 659          |   short    | 478          | mousebite  | 586          |
# |    spur    | 483          |   copper   | 464          |  pin-hole  | 470          |
# |            |              |            |              |            |              |
# |   total    | 3140         |            |              |            |              |
# [01/31 10:36:57 d2.data.common]: Serializing 500 elements to byte tensors and concatenating them all ...
# [01/31 10:36:57 d2.data.common]: Serialized dataset takes 0.28 MiB
# [01/31 10:36:57 d2.evaluation.evaluator]: Start inference on 500 images
# [01/31 10:36:59 d2.evaluation.evaluator]: Inference done 11/500. 0.1820 s / img. ETA=0:01:37
# [01/31 10:37:04 d2.evaluation.evaluator]: Inference done 36/500. 0.1815 s / img. ETA=0:01:33
# [01/31 10:37:09 d2.evaluation.evaluator]: Inference done 61/500. 0.1819 s / img. ETA=0:01:28
# [01/31 10:37:14 d2.evaluation.evaluator]: Inference done 86/500. 0.1828 s / img. ETA=0:01:24
# [01/31 10:37:20 d2.evaluation.evaluator]: Inference done 111/500. 0.1837 s / img. ETA=0:01:19
# [01/31 10:37:25 d2.evaluation.evaluator]: Inference done 135/500. 0.1844 s / img. ETA=0:01:14
# [01/31 10:37:30 d2.evaluation.evaluator]: Inference done 159/500. 0.1850 s / img. ETA=0:01:10
# [01/31 10:37:35 d2.evaluation.evaluator]: Inference done 183/500. 0.1856 s / img. ETA=0:01:05
# [01/31 10:37:40 d2.evaluation.evaluator]: Inference done 207/500. 0.1863 s / img. ETA=0:01:00
# [01/31 10:37:45 d2.evaluation.evaluator]: Inference done 231/500. 0.1868 s / img. ETA=0:00:55
# [01/31 10:37:50 d2.evaluation.evaluator]: Inference done 255/500. 0.1870 s / img. ETA=0:00:50
# [01/31 10:37:55 d2.evaluation.evaluator]: Inference done 279/500. 0.1872 s / img. ETA=0:00:45
